# %% [markdown]
# # OptiGuide Example

# %% [markdown]
# Here we give a simple example, as designed and illustrated in the [OptiGuide paper](https://arxiv.org/abs/2307.03875).
# While the original paper is designed specifically for supply chain optimization, the general framework can be easily adapted to other applications with coding capacity.

# %% [markdown]
# ## OptiGuide for Supply Chain Optimization: System Design Overview
#
# The original system design for OptiGuide, tailored for supply chain optimization, is presented below.
#
# The collaboration among three agents -- Coder, Safeguard, and Interpreter -- lies at the core of this system. They leverage a set of external tools and a large language model (LLM) to address users' questions related to supply chain applications. For a comprehensive understanding of the design and data flow, detailed information can be found in the original [paper](https://arxiv.org/abs/2307.03875).
#
#
# ![optiguide system](https://www.beibinli.com/docs/optiguide/optiguide_system.png)

# %% [markdown]
# ## New Implementation
#
#
#
# ![](new_design.png)
#
# Advantages of this multi-agent design with autogen:
# - Collaborative Problem Solving: The collaboration among the user proxy agent and the assistant agents fosters a cooperative problem-solving environment. The agents can share information and knowledge, allowing them to complement each other's abilities and collectively arrive at better solutions. On the other hand, the Safeguard acts as a virtual adversarial checker, which can perform another safety check pass on the generated code.
#
# - Modularity: The division of tasks into separate agents promotes modularity in the system. Each agent can be developed, tested, and maintained independently, simplifying the overall development process and facilitating code management.
#
# - Memory Management: The OptiGuide agent's role in maintaining memory related to user interactions is crucial. The memory retention allows the agents to have context about a user's prior questions, making the decision-making process more informed and context-aware.

# %%
# %pip install openai==0.28.1
# %pip install FLAML==2.1.1
# %pip install gurobi-machinelearning==1.3.3
# %pip install gurobipy==10.0.0
# %pip install gurobipy-pandas==1.0.0
# %pip install autogen==1.0.16
# Out:
# Collecting openai==0.28.1
#   Obtaining dependency information for openai==0.28.1 from https://files.pythonhosted.org/packages/1e/9f/385c25502f437686e4aa715969e5eaf5c2cb5e5ffa7c5cdd52f3c6ae967a/openai-0.28.1-py3-none-any.whl.metadata
#   Downloading openai-0.28.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests>=2.20 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from openai==0.28.1) (2.31.0)
# Requirement already satisfied: tqdm in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from openai==0.28.1) (4.66.1)
# Requirement already satisfied: aiohttp in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from openai==0.28.1) (3.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from requests>=2.20->openai==0.28.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from requests>=2.20->openai==0.28.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from requests>=2.20->openai==0.28.1) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from requests>=2.20->openai==0.28.1) (2023.11.17)
# Requirement already satisfied: attrs>=17.3.0 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from aiohttp->openai==0.28.1) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from aiohttp->openai==0.28.1) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from aiohttp->openai==0.28.1) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from aiohttp->openai==0.28.1) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from aiohttp->openai==0.28.1) (1.3.1)
# Using cached openai-0.28.1-py3-none-any.whl (76 kB)
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.3.7
#     Uninstalling openai-1.3.7:
#       Successfully uninstalled openai-1.3.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# optiguide 0.0.1 requires autogen, which is not installed.
# pyautogen 0.2.0 requires openai~=1.2, but you have openai 0.28.1 which is incompatible.
# Successfully installed openai-0.28.1
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: FLAML==2.1.1 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: NumPy>=1.17.0rc1 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from FLAML==2.1.1) (1.26.2)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting gurobi-machinelearning==1.3.3
#   Obtaining dependency information for gurobi-machinelearning==1.3.3 from https://files.pythonhosted.org/packages/49/8d/4899e2d75b862ff4eb4dc17aaf2c0cf04f8050c83d1cc05ed74988a37664/gurobi_machinelearning-1.3.3-py3-none-any.whl.metadata
#   Downloading gurobi_machinelearning-1.3.3-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: numpy>=1.22.0 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from gurobi-machinelearning==1.3.3) (1.26.2)
# Requirement already satisfied: gurobipy>=10.0.0 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from gurobi-machinelearning==1.3.3) (11.0.0)
# Collecting scipy>=1.9.3 (from gurobi-machinelearning==1.3.3)
#   Obtaining dependency information for scipy>=1.9.3 from https://files.pythonhosted.org/packages/4b/48/20e77ddb1f473d4717a7d4d3fc8d15557f406f7708496054c59f635b7734/scipy-1.11.4-cp311-cp311-macosx_12_0_arm64.whl.metadata
#   Downloading scipy-1.11.4-cp311-cp311-macosx_12_0_arm64.whl.metadata (165 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.4/165.4 kB 2.0 MB/s eta 0:00:0000:0100:01
# Using cached gurobi_machinelearning-1.3.3-py3-none-any.whl (66 kB)
# Downloading scipy-1.11.4-cp311-cp311-macosx_12_0_arm64.whl (29.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 15.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: scipy, gurobi-machinelearning
# Successfully installed gurobi-machinelearning-1.3.3 scipy-1.11.4
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting gurobipy==10.0.0
#   Downloading gurobipy-10.0.0-cp311-cp311-macosx_10_9_universal2.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 8.9 MB/s eta 0:00:00 0:00:01
# Installing collected packages: gurobipy
#   Attempting uninstall: gurobipy
#     Found existing installation: gurobipy 11.0.0
#     Uninstalling gurobipy-11.0.0:
#       Successfully uninstalled gurobipy-11.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# optiguide 0.0.1 requires autogen, which is not installed.
# Successfully installed gurobipy-10.0.0
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting gurobipy-pandas==1.0.0
#   Using cached gurobipy_pandas-1.0.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: gurobipy>=9.1 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from gurobipy-pandas==1.0.0) (10.0.0)
# Collecting pandas>=1.0 (from gurobipy-pandas==1.0.0)
#   Obtaining dependency information for pandas>=1.0 from https://files.pythonhosted.org/packages/d6/7c/20e737300f9bec011fb79c01d8948bc38c854876aac2da2cfcdd0992b153/pandas-2.1.3-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading pandas-2.1.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (18 kB)
# Requirement already satisfied: numpy<2,>=1.23.2 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from pandas>=1.0->gurobipy-pandas==1.0.0) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from pandas>=1.0->gurobipy-pandas==1.0.0) (2.8.2)
# Collecting pytz>=2020.1 (from pandas>=1.0->gurobipy-pandas==1.0.0)
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/32/4d/aaf7eff5deb402fd9a24a1449a8119f00d74ae9c2efa79f8ef9994261fc2/pytz-2023.3.post1-py2.py3-none-any.whl.metadata
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas>=1.0->gurobipy-pandas==1.0.0)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 7.2 MB/s eta 0:00:0000:01
# Requirement already satisfied: six>=1.5 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.0->gurobipy-pandas==1.0.0) (1.16.0)
# Downloading pandas-2.1.3-cp311-cp311-macosx_11_0_arm64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 46.7 MB/s eta 0:00:00a 0:00:01
# Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.5/502.5 kB 29.2 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, pandas, gurobipy-pandas
# Successfully installed gurobipy-pandas-1.0.0 pandas-2.1.3 pytz-2023.3.post1 tzdata-2023.3
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting autogen==1.0.16
#   Obtaining dependency information for autogen==1.0.16 from https://files.pythonhosted.org/packages/bb/4c/ec024ce118b33896f074cdea87f0eb31f79658a08e7051307168bc48103a/autogen-1.0.16-py3-none-any.whl.metadata
#   Using cached autogen-1.0.16-py3-none-any.whl.metadata (292 bytes)
# Requirement already satisfied: PyYAML in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from autogen==1.0.16) (6.0.1)
# Requirement already satisfied: autopep8 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from autogen==1.0.16) (2.0.4)
# Requirement already satisfied: docopt in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from autogen==1.0.16) (0.6.2)
# Requirement already satisfied: setuptools in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from autogen==1.0.16) (65.5.0)
# Requirement already satisfied: twine in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from autogen==1.0.16) (4.0.2)
# Requirement already satisfied: pycodestyle>=2.10.0 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from autopep8->autogen==1.0.16) (2.11.1)
# Requirement already satisfied: pkginfo>=1.8.1 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from twine->autogen==1.0.16) (1.9.6)
# Requirement already satisfied: readme-renderer>=35.0 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from twine->autogen==1.0.16) (42.0)
# Requirement already satisfied: requests>=2.20 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from twine->autogen==1.0.16) (2.31.0)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from twine->autogen==1.0.16) (1.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from twine->autogen==1.0.16) (2.1.0)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from twine->autogen==1.0.16) (6.9.0)
# Requirement already satisfied: keyring>=15.1 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from twine->autogen==1.0.16) (24.3.0)
# Requirement already satisfied: rfc3986>=1.4.0 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from twine->autogen==1.0.16) (2.0.0)
# Requirement already satisfied: rich>=12.0.0 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from twine->autogen==1.0.16) (13.7.0)
# Requirement already satisfied: zipp>=0.5 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from importlib-metadata>=3.6->twine->autogen==1.0.16) (3.17.0)
# Requirement already satisfied: jaraco.classes in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from keyring>=15.1->twine->autogen==1.0.16) (3.3.0)
# Requirement already satisfied: nh3>=0.2.14 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from readme-renderer>=35.0->twine->autogen==1.0.16) (0.2.14)
# Requirement already satisfied: docutils>=0.13.1 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from readme-renderer>=35.0->twine->autogen==1.0.16) (0.20.1)
# Requirement already satisfied: Pygments>=2.5.1 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from readme-renderer>=35.0->twine->autogen==1.0.16) (2.17.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from requests>=2.20->twine->autogen==1.0.16) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from requests>=2.20->twine->autogen==1.0.16) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from requests>=2.20->twine->autogen==1.0.16) (2023.11.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from rich>=12.0.0->twine->autogen==1.0.16) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->autogen==1.0.16) (0.1.2)
# Requirement already satisfied: more-itertools in /Users/coltonlapp/Dropbox/My Mac (Coltons-MacBook-Pro.local)/Desktop/SCHOOL/Year2_FALL/DABP/final_project/EnergyArbitrage/venv/lib/python3.11/site-packages (from jaraco.classes->keyring>=15.1->twine->autogen==1.0.16) (10.1.0)
# Using cached autogen-1.0.16-py3-none-any.whl (30 kB)
# Installing collected packages: autogen
# Successfully installed autogen-1.0.16
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# test Gurobi installation
import gurobipy as gp
from gurobipy import GRB
from eventlet.timeout import Timeout

# import auxillary packages
import requests  # for loading the example source code
import openai

# import flaml and autogen
from flaml import autogen
from flaml.autogen.agentchat import Agent, UserProxyAgent
from optiguide.optiguide import OptiGuideAgent

openai.api_key = "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"

# %%
autogen.oai.ChatCompletion.start_logging()

config_list = autogen.config_list_from_json(
    "OAI_CONFIG_LIST",
    filter_dict={
        "model": {
            # "gpt-4",
            # "gpt4",
            # "gpt-4-32k",
            # "gpt-4-32k-0314",
            "gpt-3.5-turbo",
            # "gpt-3.5-turbo-16k",
            # "gpt-3.5-turbo-0301",
            # "chatgpt-35-turbo-0301",
            # "gpt-35-turbo-v0301",
        }
    }
)

# %% [markdown]
# Now, let's import the source code (loading from URL) and also some training examples (defined as string blow).

# %%
# Get the source code of our coffee example
code_url = "https://raw.githubusercontent.com/microsoft/OptiGuide/main/benchmark/application/coffee.py"
response  = requests.get(code_url)


# Check if the request was successful
if response.status_code == 200:
    # Get the text content from the response
    code = response.text
else:
    raise RuntimeError("Failed to retrieve the file.")
# code = open(code_url, "r").read() # for local files


# show the first head and tail of the source code
print("\n".join(code.split("\n")[:10]))
print(".\n" * 3)
print("\n".join(code.split("\n")[-10:]))
# Out:
# import time
# from gurobipy import GRB, Model
#
# # Example data
#
# capacity_in_supplier = {'supplier1': 150, 'supplier2': 50, 'supplier3': 100}
#
# shipping_cost_from_supplier_to_roastery = {
#     ('supplier1', 'roastery1'): 5,
#     ('supplier1', 'roastery2'): 4,
# .
# .
# .
#
# # Solve
# m.update()
# model.optimize()
#
# print(time.ctime())
# if m.status == GRB.OPTIMAL:
#     print(f'Optimal cost: {m.objVal}')
# else:
#     print("Not solved to optimality. Optimization status:", m.status)

# %%
# In-context learning examples.
example_qa = """
----------
Question: Why is it not recommended to use just one supplier for roastery 2?
Answer Code:
```python
z = m.addVars(suppliers, vtype=GRB.BINARY, name="z")
m.addConstr(sum(z[s] for s in suppliers) <= 1, "_")
for s in suppliers:
    m.addConstr(x[s,'roastery2'] <= capacity_in_supplier[s] * z[s], "_")
```

----------
Question: What if there's a 13% jump in the demand for light coffee at cafe1?
Answer Code:
```python
light_coffee_needed_for_cafe["cafe1"] = light_coffee_needed_for_cafe["cafe1"] * (1 + 13/100)
```
"""

# %% [markdown]
# Now, let's create an OptiGuide agent and also a user.
#
# For the OptiGuide agent, we only allow "debug_times" to be 1, which means it can debug its answer once if it encountered errors.

# %%
# %%capture
agent = OptiGuideAgent(
    name="OptiGuide Coffee Example",
    source_code=code,
    debug_times=1,
    example_qa="",
    llm_config={
        "request_timeout": 600,
        "seed": 42,
        "config_list": config_list,
    }
)

user = UserProxyAgent(
    "user", max_consecutive_auto_reply=0,
    human_input_mode="NEVER", code_execution_config=False
)

# %% [markdown]
# Now, let's create a user's question.

# %%
user.initiate_chat(agent, message="What if we prohibit shipping from supplier 1 to roastery 2?")
# Out:
# user (to OptiGuide Coffee Example):
#
# What if we prohibit shipping from supplier 1 to roastery 2?
#
# --------------------------------------------------------------------------------
# OptiGuide Coffee Example (to writer):
#
#
# Answer Code:
#
#
# --------------------------------------------------------------------------------
# writer (to OptiGuide Coffee Example):
#
# ```python
# # To prohibit shipping from supplier 1 to roastery 2 (i.e., remove the path), let's add a constraint:
# model.addConstr(x[('supplier1', 'roastery2')] == 0, name='no_ship_supplier1_roastery2')
# ```
#
# --------------------------------------------------------------------------------
# OptiGuide Coffee Example (to safeguard):
#
#
# --- Code ---
# # To prohibit shipping from supplier 1 to roastery 2 (i.e., remove the path), let's add a constraint:
# model.addConstr(x[('supplier1', 'roastery2')] == 0, name='no_ship_supplier1_roastery2')
#
# --- One-Word Answer: SAFE or DANGER ---
#
#
# --------------------------------------------------------------------------------
# safeguard (to OptiGuide Coffee Example):
#
# SAFE
#
# --------------------------------------------------------------------------------
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 11 rows, 18 columns and 36 nonzeros
# Model fingerprint: 0x185e64ed
# Variable types: 0 continuous, 18 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+01, 2e+02]
# Found heuristic solution: objective 3490.0000000
# Presolve time: 0.00s
# Presolved: 11 rows, 18 columns, 36 nonzeros
# Variable types: 0 continuous, 18 integer (0 binary)
# Found heuristic solution: objective 3486.0000000
#
# Root relaxation: objective 2.470000e+03, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2470.0000000 2470.00000  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2470 3486 3490
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.470000000000e+03, best bound 2.470000000000e+03, gap 0.0000%
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[arm])
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 12 rows, 18 columns and 37 nonzeros
# Model fingerprint: 0xbb62b606
# Variable types: 0 continuous, 18 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+01, 2e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint no_ship_supplier1_roastery2 by 80.000000000
#
# Found heuristic solution: objective 3490.0000000
# Presolve removed 2 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 10 rows, 17 columns, 33 nonzeros
# Variable types: 0 continuous, 17 integer (0 binary)
# Found heuristic solution: objective 3485.0000000
#
# Root relaxation: objective 2.760000e+03, 10 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2760.0000000 2760.00000  0.00%     -    0s
#
# Explored 1 nodes (10 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2760 3485 3490
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.760000000000e+03, best bound 2.760000000000e+03, gap 0.0000%
# Mon Dec  4 17:37:02 2023
# Optimal cost: 2760.0
# Optimization problem solved. The objective value is: 2760.0
# OptiGuide Coffee Example (to writer):
#
# Here are the execution results: Optimization problem solved. The objective value is: 2760.0
#
# Can you organize these information to a human readable answer?
# Remember to compare the new results to the original results you obtained in the
# beginning.
#
# --- HUMAN READABLE ANSWER ---
#
#
# --------------------------------------------------------------------------------
# writer (to OptiGuide Coffee Example):
#
# After prohibiting the shipping of coffee from supplier 1 to roastery 2, the optimal solution of the model changed. The new optimal cost increased to 2760.0 from the previous 2470.0. This change implies an increase in the overall cost of shipping coffee beans and meeting the demand of cafes when this particular shipping route is blocked. This might be due to the necessity to choose more expensive routes to fulfill the demand, leading to an overall increase in the cost.
#
# --------------------------------------------------------------------------------
# OptiGuide Coffee Example (to user):
#
# After prohibiting the shipping of coffee from supplier 1 to roastery 2, the optimal solution of the model changed. The new optimal cost increased to 2760.0 from the previous 2470.0. This change implies an increase in the overall cost of shipping coffee beans and meeting the demand of cafes when this particular shipping route is blocked. This might be due to the necessity to choose more expensive routes to fulfill the demand, leading to an overall increase in the cost.
#
# --------------------------------------------------------------------------------

# %%
user.initiate_chat(agent, message="What is the impact of supplier1 being able to supply only half the quantity at present?")
# Out:
# user (to OptiGuide Coffee Example):
#
# What is the impact of supplier1 being able to supply only half the quantity at present?
#
# --------------------------------------------------------------------------------
# OptiGuide Coffee Example (to writer):
#
#
# Answer Code:
#
#
# --------------------------------------------------------------------------------
# writer (to OptiGuide Coffee Example):
#
# ```python
# # Update the supply capacity of supplier1 to half its current value
# capacity_in_supplier['supplier1'] = capacity_in_supplier['supplier1'] / 2
#
# # Update the model constraints related to supply capacity
# for s in suppliers:
#     model.remove(model.getConstrByName("supply_" + s))
#     model.addConstr(
#         sum(x[i] for i in shipping_cost_from_supplier_to_roastery.keys() if i[0] == s) <= capacity_in_supplier[s],
#         "supply_" + s
#     )
# model.update()
# ```
#
# --------------------------------------------------------------------------------
# OptiGuide Coffee Example (to safeguard):
#
#
# --- Code ---
# # Update the supply capacity of supplier1 to half its current value
# capacity_in_supplier['supplier1'] = capacity_in_supplier['supplier1'] / 2
#
# # Update the model constraints related to supply capacity
# for s in suppliers:
#     model.remove(model.getConstrByName("supply_" + s))
#     model.addConstr(
#         sum(x[i] for i in shipping_cost_from_supplier_to_roastery.keys() if i[0] == s) <= capacity_in_supplier[s],
#         "supply_" + s
#     )
# model.update()
#
# --- One-Word Answer: SAFE or DANGER ---
#
#
# --------------------------------------------------------------------------------
# safeguard (to OptiGuide Coffee Example):
#
# SAFE
#
# --------------------------------------------------------------------------------
# Set parameter Username
# License expired 2023-11-24
# OptiGuide Coffee Example (to writer):
#
#
#
# While running the code you suggested, I encountered the <class 'gurobipy.GurobiError'>:
# --- ERROR MESSAGE ---
# License expired 2023-11-24
#
# Please try to resolve this bug, and rewrite the code snippet.
# --- NEW CODE ---
#
#
# --------------------------------------------------------------------------------
# writer (to OptiGuide Coffee Example):
#
# The error message "License expired 2023-11-24" seems to be related to the expiration of your Gurobi license.
#
# You need to update your Gurobi license to fix this error. Here is a short instruction:
# 1. Go to the Gurobi website and log into your account.
# 2. Download a new license file.
# 3. Locate the gurobi.lic file on your computer and replace it with the new license file.
#
# If you're using Gurobi through an academic license, note that these licenses are typically limited to one year and must be renewed annually.
#
# However, if you continue to have issues, I recommend reaching out to Gurobi support for more detailed assistance.
#
# Once you have an updated license, you would be able to run the previous code to change the supply from supplier1.
#
# --------------------------------------------------------------------------------
# OptiGuide Coffee Example (to safeguard):
#
#
# --- Code ---
# The error message "License expired 2023-11-24" seems to be related to the expiration of your Gurobi license.
#
# You need to update your Gurobi license to fix this error. Here is a short instruction:
# 1. Go to the Gurobi website and log into your account.
# 2. Download a new license file.
# 3. Locate the gurobi.lic file on your computer and replace it with the new license file.
#
# If you're using Gurobi through an academic license, note that these licenses are typically limited to one year and must be renewed annually.
#
# However, if you continue to have issues, I recommend reaching out to Gurobi support for more detailed assistance.
#
# Once you have an updated license, you would be able to run the previous code to change the supply from supplier1.
#
# --- One-Word Answer: SAFE or DANGER ---
#
#
# --------------------------------------------------------------------------------
# safeguard (to OptiGuide Coffee Example):
#
# SAFE
#
# --------------------------------------------------------------------------------
# invalid syntax (<string>, line 43)
# OptiGuide Coffee Example (to user):
#
# Sorry. I cannot answer your question.
#
# --------------------------------------------------------------------------------
